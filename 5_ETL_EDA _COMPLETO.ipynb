# %% [markdown]
# # Dataset: Global Superstore
# * url: [superstore.csv](https://www.kaggle.com/code/yorkyong/global-superstore-dataset-data-exploration/input)
#
# Columnas:
#
# * **category**: The category of products sold in the superstore.
# * **city**: The city where the order was placed.
# * **country**: The country in which the superstore is located.
# * **customer_id**: A unique identifier for each customer.
# * **customer_name**: The name of the customer who placed the order.
# * **discount**: The discount applied to the order.
# * **market**: The market or region where the superstore operates.
# * **ji_lu_shu**: An unknown or unspecified column.
# * **order_date**: The date when the order was placed.
# * **order_id**: A unique identifier for each order.
# * **order_priority**: The priority level of the order.
# * **product_id**: A unique identifier for each product.
# * **product_name**: The name of the product.
# * **profit**: The profit generated from the order.
# * **quantity**: The quantity of products ordered.
# * **region**: The region where the order was placed.
# * **row_id**: A unique identifier for each row in the dataset.
# * **sales**: The total sales amount for the order.
# * **segment**: The customer segment (e.g., consumer, corporate, or home office).
# * **ship_date**: The date when the order was shipped.
# * **ship_mode**: The shipping mode used for the order.
# * **shipping_cost**: The cost of shipping for the order.
# * **state**: The state or region within the country.
# * **sub_category**: The sub-category of products within the main category.
# * **year**: The year in which the order was placed.
# * **market2**: Another column related to market information.
# * **weeknum**: The week number when the order was placed.

# %% [markdown]
# ---
# # Objetivos:
# 1. Entender el proceso ETL mediante la exploración del dataset superstore.csv.
# 2. Aplicar los conocimientos adquiridos en el método EDA sobre el dataset en mención.
# 3. Análizar el comportamiento de las compras a través de los meses, años y principales regiones.

# %% [markdown]
# ---
# # **Proceso ETL** (Extract, Transform and Load)

# %% [markdown]
# ---
# ## 1. ***"E"*** (Extract)

# %%
# Importar librerías para análisis
import pandas as pd
import numpy as np

# Importar librerías de visualización
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 200)

# Configuración de estilo
sns.set(style="darkgrid")
plt.rcParams['figure.figsize'] = (10, 4)

# %%
# Crear DataFrame
file_path = "superstore.csv"
df = pd.read_csv(file_path, encoding='latin1')

# Visualizamos las primeras filas para entender la estructura de los datos
df
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  è®°å½æ°               Order.Date  \
# 0      Lycoris Saunders       0.0     US          1  2011-01-07 00:00:00.000
# ...

# %%
df_copy = df.copy()

df_copy
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  è®°å½æ°               Order.Date  \
# 0      Lycoris Saunders       0.0     US          1  2011-01-07 00:00:00.000
# ...

# %% [markdown]
# ## 2. ***"T"*** (Transform)

# %% [markdown]
# 2.a) Limpieza y transformacion de los datos

# %%
df_copy = df.copy()
df_copy
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  è®°å½æ°               Order.Date  \
# 0      Lycoris Saunders       0.0     US          1  2011-01-07 00:00:00.000
# ...

# %%
# Verificamos información general del dataset
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   è®°å½æ°       51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
# Contar valores únicos para cada columna

          
for i_col in df_copy.columns:
    print(f'Columna: {i_col} → {len(list( pd.unique(df_copy[i_col]) ))}')
# Out:
# Columna: Category → 3
# Columna: City → 3636
# Columna: Country → 147
# Columna: Customer.ID → 4873
# Columna: Customer.Name → 795
# Columna: Discount → 27
# Columna: Market → 7
# Columna: è®°å½æ° → 1
# Columna: Order.Date → 1430
# Columna: Order.ID → 25035
# Columna: Order.Priority → 4
# Columna: Product.ID → 10292
# Columna: Product.Name → 3788
# Columna: Profit → 24575
# Columna: Quantity → 14
# Columna: Region → 13
# Columna: Row.ID → 51290
# Columna: Sales → 2246
# Columna: Segment → 3
# Columna: Ship.Date → 1464
# Columna: Ship.Mode → 4
# Columna: Shipping.Cost → 16877
# Columna: State → 1094
# Columna: Sub.Category → 17
# Columna: Year → 4
# Columna: Market2 → 6
# Columna: weeknum → 53

# %% [markdown]
# 1. Borrar las columnas tipo "**ship**" porque no me sirven para cumplir con el objetivo del análisis.
# 2. Borrar **Row.ID** porque tiene 51920 valores únicos.
# 3. Borrar **è®°å½æ°** porque se desconoce el contexto de esa columna.

# %%
# Verificar valores duplicados
df_copy.duplicated().sum()
# Out:
# 0

# %%
df_copy.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'è®°å½æ°', 'Order.Date', 'Order.ID',
#        'Order.Priority', 'Product.ID', 'Product.Name', 'Profit', 'Quantity',
#        'Region', 'Row.ID', 'Sales', 'Segment', 'Ship.Date', 'Ship.Mode',
#        'Shipping.Cost', 'State', 'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
# Eliminar columnas innecesarias
df_copy.drop(columns=['Row.ID', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'è®°å½æ°', 'Market2', 'weeknum'], inplace=True)

df_copy
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market               Order.Date  \
# 0      Lycoris Saunders       0.0     US  2011-01-07 00:00:00.000
# 1         Mark Van Huff       0.0     US  2011-01-21 00:00:00.000
# ...

# %% [markdown]
# * Se eliminaron las columnas: 'Row.ID', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'è®°å½æ°', 'Market2', 'weeknum' del dataset **df_copy**

# %%
# Volver a verificar valores duplicados
df_copy.duplicated().sum()
# Out:
# 9

# %%
df_copy.duplicated()[ df_copy.duplicated() == True ]
# Out:
# 3915     True
# 13715    True
# 18252    True
# 21836    True
# 22752    True
# 30273    True
# 45441    True
# 45745    True
# 46972    True
# dtype: bool

# %%
df_copy.iloc[3914:3916]
# Out:
#              Category   City Country Customer.ID  Customer.Name  Discount  \
# 3914  Office Supplies  Thika   Kenya    PC-90001  Pauline Chand       0.0
# 3915  Office Supplies  Thika   Kenya    PC-90001  Pauline Chand       0.0
#
#       Market               Order.Date      Order.ID Order.Priority  \
# 3914  Africa  2013-02-23 00:00:00.000  KE-2013-2790           High
# 3915  Africa  2013-02-23 00:00:00.000  KE-2013-2790           High
#
#             Product.ID                         Product.Name  Profit  Quantity  \
# 3914  OFF-CAM-10004002  Cameo Business Envelopes, Set of 50    8.19         1
# 3915  OFF-CAM-10004002  Cameo Business Envelopes, Set of 50    8.19         1
#
#       Region  Sales      Segment    State Sub.Category  Year
# 3914  Africa     20  Home Office  Central    Envelopes  2013
# 3915  Africa     20  Home Office  Central    Envelopes  2013

# %%
df.iloc[3914:3916]
# Out:
#              Category   City Country Customer.ID  Customer.Name  Discount  \
# 3914  Office Supplies  Thika   Kenya    PC-90001  Pauline Chand       0.0
# 3915  Office Supplies  Thika   Kenya    PC-90001  Pauline Chand       0.0
#
#       Market  è®°å½æ°               Order.Date      Order.ID Order.Priority  \
# 3914  Africa          1  2013-02-23 00:00:00.000  KE-2013-2790           High
# 3915  Africa          1  2013-02-23 00:00:00.000  KE-2013-2790           High
#
#             Product.ID                         Product.Name  Profit  Quantity  \
# 3914  OFF-CAM-10004002  Cameo Business Envelopes, Set of 50    8.19         1
# 3915  OFF-CAM-10004002  Cameo Business Envelopes, Set of 50    8.19         1
#
#       Region  Row.ID  Sales      Segment                Ship.Date  \
# 3914  Africa   49443     20  Home Office  2013-02-25 00:00:00.000
# 3915  Africa   49444     20  Home Office  2013-02-25 00:00:00.000
#
# ...

# %% [markdown]
# 1. Después de la eliminación de las columnas, se encontraron 9 registros únicos porque la columna **Row.ID** no permitía observar dichos registros únicos.

# %%
# Eliminar valores duplicaddos
df_copy.drop_duplicates(inplace=True)

df_copy
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market               Order.Date  \
# 0      Lycoris Saunders       0.0     US  2011-01-07 00:00:00.000
# 1         Mark Van Huff       0.0     US  2011-01-21 00:00:00.000
# ...

# %% [markdown]
# 1. Se eliminaron 9 registros duplicados.

# %%
# Convertir fecha a tipo datetime
df_copy['Order.Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51281 entries, 0 to 51289
# Series name: Order.Date
# Non-Null Count  Dtype
# --------------  -----
# 51281 non-null  object
# dtypes: object(1)
# memory usage: 801.3+ KB

# %%
df_copy['Order.Date'] = pd.to_datetime(df_copy['Order.Date'], errors='coerce' )

df_copy['Order.Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51281 entries, 0 to 51289
# Series name: Order.Date
# Non-Null Count  Dtype
# --------------  -----
# 51281 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 801.3 KB

# %%
# Crear columnas nuevas
df_copy['order_year'] = df_copy['Order.Date'].dt.year
df_copy['order_month'] = df_copy['Order.Date'].dt.month
df_copy['order_dia_semana'] = df_copy['Order.Date'].dt.dayofweek

df_copy[ ['order_year', 'order_month', 'order_dia_semana'] ]
# Out:
#        order_year  order_month  order_dia_semana
# 0            2011            1                 4
# 1            2011            1                 4
# 2            2011            8                 4
# 3            2011            8                 4
# 4            2011            9                 3
# ...           ...          ...               ...
# 51285        2014           12                 2
# 51286        2014           12                 2
# 51287        2014           12                 3
# 51288        2014           12                 3
# 51289        2014           12                 4
#
# [51281 rows x 3 columns]

# %%
df_copy.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Sales',
#        'Segment', 'State', 'Sub.Category', 'Year', 'order_year', 'order_month',
#        'order_dia_semana'],
#       dtype='object')

# %%
# Cantidad de filas con datos  nulos
df_copy.isna().sum()
# Out:
# Category            0
# City                0
# Country             0
# Customer.ID         0
# Customer.Name       0
# Discount            0
# Market              0
# Order.Date          0
# Order.ID            0
# Order.Priority      0
# Product.ID          0
# Product.Name        0
# Profit              0
# Quantity            0
# Region              0
# Sales               0
# Segment             0
# State               0
# Sub.Category        0
# Year                0
# order_year          0
# order_month         0
# order_dia_semana    0
# dtype: int64

# %% [markdown]
# 1. En el dataset original no existen valores nulos.

# %%
# Agrupar ventas por región y año
df_copy.groupby(['Region', 'order_year'])['Sales'].sum().reset_index().sort_values(by='Sales')
# Out:
#             Region  order_year   Sales
# 4           Canada        2011    8507
# 5           Canada        2012   16099
# 6           Canada        2013   19162
# 7           Canada        2014   23164
# 8        Caribbean        2011   57043
# 9        Caribbean        2012   64149
# 10       Caribbean        2013   97593
# 11       Caribbean        2014  105496
# 16    Central Asia        2011  123238
# 0           Africa        2011  127186
# 24            East        2011  128403
# 20            EMEA        2011  136422
# 49            West        2012  139978
# 1           Africa        2012  144487
# 48            West        2011  147878
# 44  Southeast Asia        2011  150067
# 33      North Asia        2012  152368
# 25            East        2012  156342
# 21            EMEA        2012  163406
# 36         Oceania        2011  171409
# 17    Central Asia        2012  174135
# 26            East        2013  180549
# 45  Southeast Asia        2012  185817
# ...

# %%
df_copy.groupby(['Region', 'order_year'])['Sales'].sum().reset_index().sort_values(by='Sales')
# Out:
#             Region  order_year   Sales
# 4           Canada        2011    8507
# 5           Canada        2012   16099
# 6           Canada        2013   19162
# 7           Canada        2014   23164
# 8        Caribbean        2011   57043
# 9        Caribbean        2012   64149
# 10       Caribbean        2013   97593
# 11       Caribbean        2014  105496
# 16    Central Asia        2011  123238
# 0           Africa        2011  127186
# 24            East        2011  128403
# 20            EMEA        2011  136422
# 49            West        2012  139978
# 1           Africa        2012  144487
# 48            West        2011  147878
# 44  Southeast Asia        2011  150067
# 33      North Asia        2012  152368
# 25            East        2012  156342
# 21            EMEA        2012  163406
# 36         Oceania        2011  171409
# 17    Central Asia        2012  174135
# 26            East        2013  180549
# 45  Southeast Asia        2012  185817
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          51281 non-null  object
#  1   City              51281 non-null  object
#  2   Country           51281 non-null  object
#  3   Customer.ID       51281 non-null  object
#  4   Customer.Name     51281 non-null  object
#  5   Discount          51281 non-null  float64
#  6   Market            51281 non-null  object
#  7   Order.Date        51281 non-null  datetime64[ns]
#  8   Order.ID          51281 non-null  object
#  9   Order.Priority    51281 non-null  object
#  10  Product.ID        51281 non-null  object
#  11  Product.Name      51281 non-null  object
#  12  Profit            51281 non-null  float64
#  13  Quantity          51281 non-null  int64
#  14  Region            51281 non-null  object
#  15  Sales             51281 non-null  int64
# ...

# %% [markdown]
# **Método EDA** (Exploratoty Data Analysis)

# %% [markdown]
# ### 2.b) **Estadística descriptiva**

# %%
df_copy.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Sales',
#        'Segment', 'State', 'Sub.Category', 'Year', 'order_year', 'order_month',
#        'order_dia_semana'],
#       dtype='object')

# %%
# Estadísticas de variables numéricas
df_copy.describe()
# Out:
#            Discount                     Order.Date        Profit  \
# count  51281.000000                          51281  51281.000000
# mean       0.142918  2013-05-11 22:13:05.834909440     28.612904
# min        0.000000            2011-01-01 00:00:00  -6599.978000
# 25%        0.000000            2012-06-19 00:00:00      0.000000
# 50%        0.000000            2013-07-08 00:00:00      9.240000
# 75%        0.200000            2014-05-22 00:00:00     36.810000
# max        0.850000            2014-12-31 00:00:00   8399.976000
# std        0.212292                            NaN    174.355838
#
#            Quantity         Sales          Year    order_year   order_month  \
# count  51281.000000  51281.000000  51281.000000  51281.000000  51281.000000
# mean       3.476726    246.512919   2012.777286   2012.777286      7.522747
# min        1.000000      0.000000   2011.000000   2011.000000      1.000000
# ...

# %%
# Estadísticas de variables no numéricas
df_copy.describe(exclude=['float64', 'int64', 'int32'], include='object')
# Out:
#                Category           City        Country Customer.ID  \
# count             51281          51281          51281       51281
# unique                3           3636            147        4873
# top     Office Supplies  New York City  United States   JG-158051
# freq              31268            915           9993          40
#
#           Customer.Name Market        Order.ID Order.Priority  \
# count             51281  51281           51281          51281
# unique              795      7           25035              4
# top     Muhammed Yedwab   APAC  CA-2014-100111         Medium
# freq                108  10999              14          29426
#
#              Product.ID Product.Name   Region   Segment       State  \
# count             51281        51281    51281     51281       51281
# unique            10292         3788       13         3        1094
# top     OFF-AR-10003651      Staples  Central  Consumer  California
# ...

# %% [markdown]
# ### 2.b) **Visualizaciones**
# * Detección de outliers.
# * Detección de patrones y anomalías.

# %%
# Distribución de variables numéricas- medir frecuencia de categorias en una variable
for i_grafica in ['Year', 'Quantity','Discount']:
    sns.histplot(data=df_copy,x=i_grafica,kde=True)
    plt.show()
 # ·'float64', 'int64', 'int32'
   # kde=True permite ver la densidad estimada

# %%
# Grafico solo de los años 
sns.histplot(data=df_copy,x='Year')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
# Boxplots para detectar outliers.. valores atipicos
for i_grafica in ['Discount','Profit','Quantity','Sales']:
    sns.boxplot(data=df_copy,y=i_grafica)
    plt.show()

# %%
# Relación entre descuento y ganancia
sns.scatterplot(data=df, x='Discount', y='Profit', hue='Category')

# Para el nombre del Grafico
plt.title('Relacion entre descuento y ganancia')
# para el nombre dek eje x
plt.xlabel('Discount')
# para el nombre del eje y 
plt.ylabel('Profit')
# para los ejes, rotacion 
plt.xticks(rotation=45)
# para que aprezca la malla
plt.grid(True)
# para imprimir el grafico
plt.show()

# %%
# Ganancia por categoría- grafico barplot
sns.barplot(data=df, x='Category', y='Profit')
# Para el nombre del Grafico
plt.title('Ganancia total por categoria')
# para el nombre dek eje x
plt.xlabel('Category')
# para el nombre del eje y 
plt.ylabel('Profit')
# para los ejes, rotacion 
plt.xticks(rotation=45)
# para que aprezca la malla
plt.grid(True)
# para imprimir el grafico
plt.show()

# %%
# Ganancia por subcategoría ,
# El gráfico que muestras es un gráfico de barras (bar plot) que representa la ganancia total por subcategoría (Sub-Category) con barras de error

sns.barplot(data=df, x='Sub.Category', y='Profit')
plt.title('Ganancia total por sub categoria')

# para el nombre dek eje x
plt.xlabel('Sub.Category')
# para el nombre del eje y 
plt.ylabel('Profit')
# para los ejes, rotacion 
plt.xticks(rotation=90)
# para que aprezca la malla
plt.grid(True)
# para imprimir el grafico
plt.show()

# %%
# Ventas por año
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='Year', y='Sales',  marker='o')
plt.title('Ventas Anuales')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
# Productos más vendidos
top_subcategories = df['Product.Name'].value_counts().head(10)

# 4. Graficar
sns.barplot(x=top_subcategories.values, y=top_subcategories.index)
plt.title('Top 10 Productos más vendidos')
plt.xlabel('Cantidad de ventas')
plt.ylabel('Nombre Productos')
plt.show()

# %%
# Productos más rentables
productos_rentables = df.groupby('Product.Name')['Profit'].sum().sort_values(ascending=False).head(10)

# Gráfico de barras horizontal
sns.barplot(x=productos_rentables.values, y=productos_rentables.index)
plt.title('Top 10 Productos más rentables')
plt.xlabel('Ganancia total (Profit)')
plt.ylabel('Product Name')
plt.tight_layout()
plt.show()

# %%
# Distribución de las Ganancias
sns.histplot(df['Profit'], kde=True, color='green')
plt.title('Distribución de Ganancias')
plt.xlabel('Ganancia')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
# Ventas por Categoría y Subcategoría- con hisplot. con el hue resalto las categorias con colores, se coloca la subcategoria para la division
sns.histplot(data=df_copy,x='Sub.Category',hue='Category')
# Para el nombre del Grafico
plt.title('Ventas Vs Subcategorias')
# para el nombre dek eje x
plt.xlabel('Sub_categorias')
# para el nombre del eje y 
plt.ylabel('Cantidad de ventas')
# para los ejes, rotacion 
plt.xticks(rotation=45)
# para que aprezca la malla
plt.grid(True)
# para imprimir el grafico
plt.show()

# %%
# Ventas Totales por Región
region_sales = df.groupby('Region')['Sales'].sum()
sns.barplot(x=region_sales.index, y=region_sales.values, palette="coolwarm")

plt.title('Ventas Totales por Región')
plt.xlabel('Región')
plt.ylabel('Ventas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17288\2909703262.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales.index, y=region_sales.values, palette="coolwarm")

# %% [markdown]
# ---
# ## 3. ***"L"*** (Load)
# * Cargar el conjunto de datos limpio y los datos transformados a un nuevo archivo o base de datos

# %%
# Guardar el dataframe limpio como CSV

archivo_proc esado = 'superstore_data_limpio.csv'
# con el index se borran los indices que salen en la data la primera columa de o en adelante
df_copy.to_csv(archivo_procesado, index=True)
print(f'El conjunto de datos luego del procesamiento fue almacenado en la ruta:\n\t{archivo_procesado}')
# Out:
# El conjunto de datos luego del procesamiento fue almacenado en la ruta:
# 	superstore_data_limpio.csv

# %%
df_model =pd.read_csv('superstore_data_limpio.csv')
df_model
# Out:
#        Unnamed: 0         Category         City        Country Customer.ID  \
# 0               0  Office Supplies  Los Angeles  United States   LS-172304
# 1               1  Office Supplies  Los Angeles  United States   MV-174854
# 2               2  Office Supplies  Los Angeles  United States   CS-121304
# 3               3  Office Supplies  Los Angeles  United States   CS-121304
# 4               4  Office Supplies  Los Angeles  United States   AP-109154
# ...           ...              ...          ...            ...         ...
# 51276       51285  Office Supplies  Los Angeles  United States   AM-103604
# 51277       51286  Office Supplies  Los Angeles  United States   AM-103604
# 51278       51287  Office Supplies  Los Angeles  United States   HR-147704
# 51279       51288  Office Supplies  Los Angeles  United States   RM-196754
# 51280       51289  Office Supplies  Los Angeles  United States   FH-143654
#
# ...

# %%
df_model.info
# Out:
# <bound method DataFrame.info of               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51276  Office Supplies  Los Angeles  United States   AM-103604
# 51277  Office Supplies  Los Angeles  United States   AM-103604
# 51278  Office Supplies  Los Angeles  United States   HR-147704
# 51279  Office Supplies  Los Angeles  United States   RM-196754
# 51280  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# 0      Lycoris Saunders       0.0     US  2011-01-07  CA-2011-130813
# ...
